# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
tips = pd.read_csv('data.csv')
tips.head()
# Out:
#   function   deg         value
# 0      SRE  deg0      0.934679
# 1      LRE  deg0     45.657676
# 2      GLN  deg0   1103.217499
# 3      RLN  deg0  99681.167925
# 4       RP  deg0      1.166057

# %%
sns.distplot(tips['value'])

# %%
sns.boxplot(x = 'deg',y= 'value', data = tips,hue = 'function')
